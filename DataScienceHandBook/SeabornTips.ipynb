# %% [markdown]
# ## Hello Seaborn

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
fifa_filepath = "data/fifa.csv"

# Read the file into a variable fifa_data
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %%
fifa_data['ARG']
# Out:
# Date
# 1993-08-08     5.0
# 1993-09-23    12.0
# 1993-10-22     9.0
# 1993-11-19     9.0
# 1993-12-23     8.0
#               ...
# 2018-02-15     4.0
# 2018-03-15     4.0
# 2018-04-12     5.0
# 2018-05-17     5.0
# 2018-06-07     5.0
# Name: ARG, Length: 286, dtype: float64

# %%
# calculate summary stats
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import var
from numpy import std
# seed the random number generator
seed(1)
# generate univariate observations
data = 5 * randn(10000) + 50
# calculate statistics
print('Mean: %.3f' % mean(data))
print('Variance: %.3f' % var(data))
print('Standard Deviation: %.3f' % std(data))
# Out:
# Mean: 50.049
# Variance: 24.939
# Standard Deviation: 4.994

# %%
from numpy.random import seed
from numpy.random import randn
from scipy.stats import pearsonr
# seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)
# calculate Pearson's correlation
corr, p = pearsonr(data1, data2)
# display the correlation
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.888

# %%
corr = fifa_data.corr(method ='pearson') #por defecto Pearson ¿existe relación lineal entre variables?

plt.figure(figsize=(45,27))
#Mostramos solo la diagonal inferior.
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corr,mask=mask,vmin=-1, vmax=1, center=0,cmap=sns.diverging_palette(20, 220, n=200), square=True, annot=True, fmt=".2f")
# Out:
# <ipython-input-14-5a3d044adc2d>:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype=np.bool))
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data=fifa_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Datos FIFA")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=fifa_data['ARG'], label="Argentina")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=fifa_data['BRA'], label="Brazil")

# Add label for horizontal axis
plt.xlabel("Date")
plt.ylabel("Partidos")
# Out:
# Text(0, 0.5, 'Partidos')

# %%
reviews = pd.read_csv('data/winemag-data-130k-v2.csv')
corr = reviews.corr(method ='pearson') #por defecto Pearson ¿existe relación lineal entre variables?

plt.figure(figsize=(45,27))
#Mostramos solo la diagonal inferior.
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corr,mask=mask,vmin=-1, vmax=1, center=0,cmap=sns.diverging_palette(20, 220, n=200), square=True, annot=True, fmt=".2f")
# Out:
# <ipython-input-27-70d783d1bbb4>:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype=np.bool))
# <AxesSubplot:>

# %%
reviews[reviews['taster_twitter_handle'].isnull()]
# Out:
#         Unnamed: 0  country  \
# 3                3       US
# 8                8  Germany
# 15              15  Germany
# 19              19       US
# 20              20       US
# ...            ...      ...
# 129920      129920       US
# 129929      129929    Italy
# 129940      129940       US
# 129946      129946  Germany
# 129966      129966  Germany
#
#                                               description  \
# 3       Pineapple rind, lemon pith and orange blossom ...
# 8       Savory dried thyme notes accent sunnier flavor...
# 15      Zesty orange peels and apple notes abound in t...
# 19      Red fruit aromas pervade on the nose, with cig...
# 20      Ripe aromas of dark berries mingle with ample ...
# ...                                                   ...
# 129920  Shows the clean, citrus acid juiciness and sil...
# 129929  This luminous sparkler has a sweet, fruit-forw...
# 129940  This is the winery's bells and whistles Chardo...
# 129946  Plump, clingy peach and honey notes are cut wi...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                    designation  points  price     province  \
# 3                         Reserve Late Harvest      87   13.0     Michigan
# 8                                        Shine      87   12.0  Rheinhessen
# 15                                       Devon      87   24.0        Mosel
# 19                                         NaN      87   32.0     Virginia
# 20                               Vin de Maison      87   23.0     Virginia
# ...                                        ...     ...    ...          ...
# 129920                     Fiddlestix Vineyard      91   48.0   California
# 129929                                     NaN      91   38.0       Veneto
# 129940                         Watson Vineyard      91   36.0   California
# 129946                                     Dom      90   17.0        Mosel
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0        Mosel
#
#                               region_1       region_2         taster_name  \
# 3                  Lake Michigan Shore            NaN  Alexander Peartree
# 8                                  NaN            NaN  Anna Lee C. Iijima
# 15                                 NaN            NaN  Anna Lee C. Iijima
# 19                            Virginia            NaN  Alexander Peartree
# 20                            Virginia            NaN  Alexander Peartree
# ...                                ...            ...                 ...
# 129920                 Sta. Rita Hills  Central Coast                 NaN
# 129929  Prosecco Superiore di Cartizze            NaN                 NaN
# 129940                       Mendocino            NaN                 NaN
# 129946                             NaN            NaN  Anna Lee C. Iijima
# 129966                             NaN            NaN  Anna Lee C. Iijima
#
#        taster_twitter_handle  \
# 3                        NaN
# 8                        NaN
# 15                       NaN
# 19                       NaN
# 20                       NaN
# ...                      ...
# 129920                   NaN
# 129929                   NaN
# 129940                   NaN
# 129946                   NaN
# 129966                   NaN
#
#                                                     title         variety  \
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 8       Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...  Gewürztraminer
# 15            Richard Böcking 2013 Devon Riesling (Mosel)        Riesling
# 19                   Quiévremont 2012 Meritage (Virginia)        Meritage
# 20          Quiévremont 2012 Vin de Maison Red (Virginia)       Red Blend
# ...                                                   ...             ...
# 129920  Pali 2006 Fiddlestix Vineyard Pinot Noir (Sta....      Pinot Noir
# 129929  Col Vetoraz Spumanti NV  Prosecco Superiore di...        Prosecco
# 129940  Standish 2006 Watson Vineyard Chardonnay (Mend...      Chardonnay
# 129946  Bischöfliche Weingüter Trier 2013 Dom Riesling...        Riesling
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
#
#                                           winery
# 3                                     St. Julian
# 8                                    Heinz Eifel
# 15                               Richard Böcking
# 19                                   Quiévremont
# 20                                   Quiévremont
# ...                                          ...
# 129920                                      Pali
# 129929                      Col Vetoraz Spumanti
# 129940                                  Standish
# 129946              Bischöfliche Weingüter Trier
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
#
# [31213 rows x 14 columns]

# %%
plt.figure(figsize=(14,10))
# Bar chart showing average score for racing games by platform
sns.barplot(x=reviews['points'], y=reviews.country) # Your code here
# Out:
# <AxesSubplot:xlabel='points', ylabel='country'>

# %%
reviews.groupby('country').points.mean()
# Out:
# country
# Argentina                 86.710263
# Armenia                   87.500000
# Australia                 88.580507
# Austria                   90.101345
# Bosnia and Herzegovina    86.500000
# Brazil                    84.673077
# Bulgaria                  87.936170
# Canada                    89.369650
# Chile                     86.493515
# China                     89.000000
# Croatia                   87.219178
# Cyprus                    87.181818
# Czech Republic            87.250000
# Egypt                     84.000000
# England                   91.581081
# France                    88.845109
# Georgia                   87.686047
# Germany                   89.851732
# Greece                    87.283262
# Hungary                   89.191781
# India                     90.222222
# Israel                    88.471287
# Italy                     88.562231
# Lebanon                   87.685714
# Luxembourg                88.666667
# Macedonia                 86.833333
# Mexico                    85.257143
# Moldova                   87.203390
# Morocco                   88.571429
# New Zealand               88.303030
# Peru                      83.562500
# Portugal                  88.250220
# Romania                   86.400000
# Serbia                    87.500000
# Slovakia                  87.000000
# Slovenia                  88.068966
# South Africa              88.056388
# Spain                     87.288337
# Switzerland               88.571429
# Turkey                    88.088889
# US                        88.563720
# Ukraine                   84.071429
# Uruguay                   86.752294
# Name: points, dtype: float64

# %%
ign_filepath = "data/ign_scores.csv"

# Fill in the line below to read the file into a variable ign_data
ign_data = pd.read_csv(ign_filepath, index_col="Platform", parse_dates=True)

# %%
ign_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, Dreamcast to iPhone
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Action             21 non-null     float64
#  1   Action, Adventure  21 non-null     float64
#  2   Adventure          21 non-null     float64
#  3   Fighting           21 non-null     float64
#  4   Platformer         21 non-null     float64
#  5   Puzzle             21 non-null     float64
#  6   RPG                21 non-null     float64
#  7   Racing             21 non-null     float64
#  8   Shooter            21 non-null     float64
#  9   Simulation         21 non-null     float64
#  10  Sports             21 non-null     float64
#  11  Strategy           21 non-null     float64
# dtypes: float64(12)
# memory usage: 2.7+ KB

# %%
# Set the width and height of the figure
plt.figure(figsize=(8, 6))
# Bar chart showing average score for racing games by platform
sns.barplot(x=ign_data['Racing'], y=ign_data.index)
# Add label for horizontal axis
plt.xlabel("")
# Add label for vertical axis
plt.title("Average Score for Racing Games, by Platform")
# Out:
# Text(0.5, 1.0, 'Average Score for Racing Games, by Platform')

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,10))
# Heatmap showing average game score by platform and genre
sns.heatmap(ign_data, annot=True)
# Add label for horizontal axis
plt.xlabel("Genre")
# Add label for vertical axis
plt.title("Average Game Score, by Platform and Genre")
# Out:
# Text(0.5, 1.0, 'Average Game Score, by Platform and Genre')

# %%
sns.scatterplot(x=ign_data['Racing'], y=ign_data['RPG'])
# Out:
# <AxesSubplot:xlabel='Racing', ylabel='RPG'>

# %%
sns.regplot(x=ign_data['Racing'], y=ign_data['RPG'])
# Out:
# <AxesSubplot:xlabel='Racing', ylabel='RPG'>

# %%
# Path of the file to read
candy_filepath = "data/candy.csv"

# Fill in the line below to read the file into a variable candy_data
candy_data = pd.read_csv(candy_filepath, index_col="id", parse_dates=True)

sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate", data=candy_data)

# %%
#Scatter plot showing the relationship between 'chocolate' and 'winpercent'
sns.swarmplot(x=candy_data['chocolate'], y=candy_data['winpercent'])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>

# %%
import sqlite3
con = sqlite3.connect('example.db')

# %%
cur = con.cursor()

# Create table
cur.execute('''CREATE TABLE stocks
               (date text, trans text, symbol text, qty real, price real)''')

# Insert a row of data
cur.execute("INSERT INTO stocks VALUES ('2006-01-05','BUY','RHAT',100,35.14)")

# Save (commit) the changes
con.commit()

# We can also close the connection if we are done with it.
# Just be sure any changes have been committed or they will be lost.
con.close()

# %%
import sqlite3
con = sqlite3.connect('example.db')
cur = con.cursor()

for row in cur.execute('SELECT * FROM stocks ORDER BY price'):
    print(row)
# Out:
# ('2006-01-05', 'BUY', 'RHAT', 100.0, 35.14)
